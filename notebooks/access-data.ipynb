# %%
import pandas as pd

folderpath = "../data/extracted"

# %%
filepath = f"{folderpath}/FordA_TRAIN.csv.gz"

df_train = pd.read_csv(filepath)

# %%
df_train.head()
# Out:
#    class         0         1         2         3         4         5  \
# 0   -1.0 -0.797172 -0.664392 -0.373015  0.040815  0.526936  0.984288
# 1    1.0  0.804855  0.634629  0.373474  0.038343 -0.340988 -0.740860
# 2   -1.0  0.727985  0.111284 -0.499124 -1.068629 -1.578351 -1.990534
# 3   -1.0 -0.234439 -0.502157 -0.732488 -0.946128 -1.139739 -1.323336
# 4   -1.0 -0.171328 -0.062285  0.235829  0.710396  1.239969  1.649823
#
#           6         7         8  ...       491       492       493       494  \
# 0  1.353120  1.578108  1.659251  ...  0.722417  0.362068  0.092083 -0.081268
# 1 -1.109667 -1.395357 -1.570192  ...  0.049213 -0.258138 -0.510583 -0.683647
# 2 -2.302031 -2.503403 -2.585211  ...  0.463685  0.507735  0.517174  0.504588
# 3 -1.490243 -1.607077 -1.620430  ... -0.929437 -0.922761 -0.929437 -0.909409
# 4  1.876321  1.865535  1.703751  ...  0.725496  0.697453  0.731967  0.808545
#
#         495       496       497       498       499  500
# ...
